# %% [markdown]
# # Проекты по аналитике данных
#
# Учебные проекты, выполненные на курсе "Аналитик данных" Яндекс.Практикум
#
# Проект                             | Описание проекта | Используемые библиотеки
# -----------------------------------| -----------------|------------------------
# Маркетинговая и продуктовая аналитика для сервиса Яндекс.Афиша | Анализ источников трафика, посещаемости сервиса, поведения пользователей и лояльности клиентов. Расчет маркетинговых и продуктовых метрик, метрик электронной коммерции. | *pandas, matplotlib, numpy, seaborn*
# Определение перспективного тарифа для федерального оператора сотовой связи | Анализ поведения клиентов оператора, пользующихся двумя разными тарифами. Определение лучшего тарифа
#
# Исследование надежности заемщиков для кредитного отдела банка  |                  |*pandas*
